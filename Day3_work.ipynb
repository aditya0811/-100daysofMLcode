# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya0811/-100daysofMLcode/blob/master/Day3_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Visualising data**

# %%
df.hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ac8f74898>,
# ...
#       dtype=object)

# %% [markdown]
# **General plot function**

# %%
df['households'].plot(kind="hist")

# %%
df['total_bedrooms'].value_counts()
# Out:
# 314.0     15
# 270.0     12
# 299.0     11
# 274.0     10
# 298.0     10
# 348.0     10
# 301.0     10
# 528.0     10
# 493.0     10
# 292.0     10
# 458.0     10
# 459.0     10
# 331.0      9
# 545.0      9
# 510.0      9
# 316.0      9
# 328.0      9
# 347.0      9
# 519.0      9
# 393.0      9
# 374.0      9
# 216.0      9
# 312.0      9
# 287.0      9
# 256.0      9
# 460.0      9
# 327.0      8
# 297.0      8
# 422.0      8
# 320.0      8
#           ..
# 405.0      1
# 702.0      1
# 521.0      1
# 869.0      1
# 1181.0     1
# 1565.0     1
# 2055.0     1
# 1095.0     1
# 1411.0     1
# 1710.0     1
# 923.0      1
# 1271.0     1
# 1827.0     1
# 846.0      1
# 1011.0     1
# 57.0       1
# 656.0      1
# 752.0      1
# 43.0       1
# 86.0       1
# 784.0      1
# 1179.0     1
# 651.0      1
# 1191.0     1
# 1122.0     1
# 1910.0     1
# 1594.0     1
# 873.0      1
# 1721.0     1
# 1105.0     1
# Name: total_bedrooms, Length: 1055, dtype: int64

# %%
df['total_rooms'].value_counts().plot(kind="pie")

# %% [markdown]
# **Scatter plot**

# %%
pd.plotting.scatter_matrix(df,figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ac1e4e198>,
# ...
#       dtype=object)

# %% [markdown]
# **Box plot**
# It is used for estimating outliears and Inter Quantile range

# %%
from IPython.display import Image
from IPython.core.display import HTML 
#box plot normal distribution
Image(url= "https://cdn-images-1.medium.com/max/800/1*NRlqiZGQdsIyAu0KzP7LaQ.png")
# Out:
# <img src="https://cdn-images-1.medium.com/max/800/1*NRlqiZGQdsIyAu0KzP7LaQ.png"/>

# %%
#box plot in general
Image(url= "https://cdn-images-1.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png")
# Out:
# <img src="https://cdn-images-1.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png"/>

# %% [markdown]
# **To return all rows of a particular value **

# %%
df_m=df[df['total_bedrooms']==13]
df_m.head()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 742    -122.22     37.88                20.0         95.0            13.0
#
#      population  households  median_income  median_house_value
# 742        31.0        15.0         2.4444            475000.0

# %% [markdown]
# **Comparing using histograms on basis of different values in a column by defining common index **

# %%
#dfa,dfb are two tables separated using column values
ind=df1["othercolumn"].value_counts().index
df1["othercolumn"].value_counts()[ind].plot(kind='bar')
df2["othercolumn"].value_counts()[ind].plot(kind='bar')
