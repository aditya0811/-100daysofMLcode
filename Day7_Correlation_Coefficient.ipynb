# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya0811/-100daysofMLcode/blob/master/Day7_Correlation_Coefficient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
Image('cr.png')

# %% [markdown]
# In plot 3 the correlation co-efficient turns out to be zero,as for first half it is -1 and for second half it is +1.

# %%
Image('cr2.png')

# %% [markdown]
# Sometimes co-relation coefficient(r) can be misleading,above both the graphs have same r(both are picked from Anscombe's quartet) but when plotted represent different data.
